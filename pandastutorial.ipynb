# %%
import pandas

# %%
import pandas as pd

# %%
pd.show_versions
# Out:
# <function pandas.util._print_versions.show_versions(as_json: 'str | bool' = False) -> 'None'>

# %%
pd.show_versions
# Out:
# <function pandas.util._print_versions.show_versions(as_json: 'str | bool' = False) -> 'None'>

# %%
pd.show_versions
# Out:
# <function pandas.util._print_versions.show_versions(as_json: 'str | bool' = False) -> 'None'>

# %%
pd.show_versions()
# Out:
# C:\Users\Famochy\anaconda3\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 4bfe3d07b4858144c219b9346329027024102ab6
# python           : 3.9.12.final.0
# python-bits      : 32
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19043
# machine          : x86
# processor        : x86 Family 6 Model 42 Stepping 7, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.4.2
# numpy            : 1.21.5
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.2.4
# setuptools       : 61.2.0
# Cython           : 0.29.28
# pytest           : 7.1.1
# hypothesis       : None
# sphinx           : 4.4.0
# blosc            : None
# feather          : None
# ...

# %%
pd.show_versions?

# %%
pd.read_csv?

# %%
df=pd.read_csv('C:\\Users\\Famochy\\data\\olympics.csv', skiprows=4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
df[['City', 'Edition']]
# Out:
#           City  Edition
# 0       Athens     1896
# 1       Athens     1896
# 2       Athens     1896
# 3       Athens     1896
# 4       Athens     1896
# ...        ...      ...
# 29211  Beijing     2008
# 29212  Beijing     2008
# 29213  Beijing     2008
# 29214  Beijing     2008
# 29215  Beijing     2008
#
# [29216 rows x 2 columns]

# %%
df.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(df.NOC)
# Out:
# pandas.core.series.Series

# %%
df=pd.read_csv('C:\\Users\\Famochy\\data\\olympics.csv', skiprows=4)
display(df)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
df.shape
# Out:
# (29216, 10)

# %%
df.shape[0]
# Out:
# 29216

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
df=pd.read_csv('C:\\Users\\Famochy\\data\\olympics.csv', skiprows=4)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
df.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
df.sort_values(['City']).head(10)
# Out:
#            City  Edition      Sport Discipline                     Athlete  \
# 5177  Amsterdam     1928  Athletics  Athletics  HEDGES, Benjamen Van Doren
# 5398  Amsterdam     1928   Football   Football         GAINZARAIN, Enrique
# 5399  Amsterdam     1928   Football   Football                GOMEZ, S. N.
# 5400  Amsterdam     1928   Football   Football                  HELMAN, A.
# 5401  Amsterdam     1928   Football   Football       MEDICI, Angel Segundo
# 5402  Amsterdam     1928   Football   Football          MONTI, Luis Felipe
# 5403  Amsterdam     1928   Football   Football                   OCHOA, P.
# 5397  Amsterdam     1928   Football   Football            FERREIRA, Manuel
# 5404  Amsterdam     1928   Football   Football          ORLANDINI, Rodolfo
# 5406  Amsterdam     1928   Football   Football       PATERNOSTER, Fernando
#
#       NOC Gender      Event Event_gender   Medal
# 5177  USA    Men  high jump            M  Silver
# ...

# %%
df.Athlete.sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
df.sort_values(['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
df[(df.Medal == 'Gold') & ~(df.Gender == 'Women')]
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
df[df.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
df[['Event','Athlete', 'Medal']][df.Athlete.str.contains('OWENS, Jesse')].value_counts()
# Out:
# Event         Athlete       Medal
# 100m          OWENS, Jesse  Gold     1
# 200m          OWENS, Jesse  Gold     1
# 4x100m relay  OWENS, Jesse  Gold     1
# long jump     OWENS, Jesse  Gold     1
# dtype: int64

# %%
df.Discipline.value_counts()
# Out:
# Athletics          3448
# Rowing             2523
# Swimming           2439
# Artistic G.        2103
# Fencing            1547
# Football           1387
# Hockey             1325
# Shooting           1105
# Sailing            1061
# Basketball          940
# Canoe / Kayak F     912
# Handball            886
# Water polo          880
# Volleyball          862
# Boxing              842
# Cycling Track       692
# Wrestling Free.     591
# Wrestling Gre-R     549
# Weightlifting       548
# Judo                435
# Diving              356
# Baseball            335
# Eventing            313
# Jumping             312
# Archery             305
# Cycling Road        303
# Tennis              272
# Dressage            255
# Rugby               192
# Softball            180
# Modern Pentath.     174
# Synchronized S.     153
# Badminton           120
# Table Tennis        120
# Tug of War           94
# Rhythmic G.          93
# Canoe / Kayak S      90
# Taekwondo            80
# ...

# %%
df[['Athlete', 'City', 'Gender', 'Medal', 'Discipline']][(df.Gender == 'Men') & (df.Medal == 'Gold') & (df.Discipline.str.contains('Badminton'))].sort_values('Athlete')
# Out:
#                        Athlete       City Gender Medal Discipline
# 20045        BUDI KUSUMA, Alan  Barcelona    Men  Gold  Badminton
# 23701            GUNAWAN, Tony     Sydney    Men  Gold  Badminton
# 25718             HA, Tae-Kwon     Athens    Men  Gold  Badminton
# 25734          HIDAYAT, Taufik     Athens    Men  Gold  Badminton
# 21787  HOYER-LARSEN, Poul Erik    Atlanta    Men  Gold  Badminton
# 23717              JI, Xinpeng     Sydney    Men  Gold  Badminton
# 27725             KIDO, Markis    Beijing    Men  Gold  Badminton
# 25719           KIM, Dong Moon     Athens    Men  Gold  Badminton
# 21773           KIM, Dong Moon    Atlanta    Men  Gold  Badminton
# 20031            KIM, Moon-Soo  Barcelona    Men  Gold  Badminton
# 27727             LEE, Yongdae    Beijing    Men  Gold  Badminton
# 27741                 LIN, Dan    Beijing    Men  Gold  Badminton
# 21771     MAINAKY, Rexy Ronald    Atlanta    Men  Gold  Badminton
# ...

# %%
df[['NOC']][(df.Edition >= 1984)].value_counts().head(3)
# Out:
# NOC
# USA    1837
# AUS     762
# GER     691
# dtype: int64

# %%
df[['Athlete', 'Gender', 'Medal', 'Edition', 'Event']][(df.Medal == 'Gold') & (df.Event == '100m') & (df.Gender == 'Men')].sort_values('Edition', ascending=False)
# Out:
#                      Athlete Gender Medal  Edition Event
# 27552            BOLT, Usain    Men  Gold     2008  100m
# 25539         GATLIN, Justin    Men  Gold     2004  100m
# 23521        GREENE, Maurice    Men  Gold     2000  100m
# 21598        BAILEY, Donovan    Men  Gold     1996  100m
# 19859      CHRISTIE, Linford    Men  Gold     1992  100m
# 18284            LEWIS, Carl    Men  Gold     1988  100m
# 16794            LEWIS, Carl    Men  Gold     1984  100m
# 15374           WELLS, Allan    Men  Gold     1980  100m
# 14069       CRAWFORD, Hasely    Men  Gold     1976  100m
# 12902         BORZOV, Valery    Men  Gold     1972  100m
# 11865       HINES, James Ray    Men  Gold     1968  100m
# 10823          HAYES, Robert    Men  Gold     1964  100m
# 9924             HARY, Armin    Men  Gold     1960  100m
# 9009   MORROW, Robert Joseph    Men  Gold     1956  100m
# 8121         REMIGINO, Lindy    Men  Gold     1952  100m
# ...

# %%
df.Event.value_counts()
# Out:
# football                          1387
# hockey                            1325
# team competition                  1018
# basketball                         940
# eight with coxswain (8+)           918
#                                   ...
# 8m class C                           2
# - 47.63kg (flyweight)                2
# 47.63 - 52.16kg (bantamweight)       2
# 65.77 - 71.67kg (middleweight)       2
# open class A                         1
# Name: Event, Length: 577, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fo=df[df.Edition == 1896]

# %%
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %% [markdown]
# Line Plot

# %%
fo.Sport.value_counts().plot(kind='line');

# %%
fo.Sport.value_counts().plot(kind='bar');

# %%
fo.Sport.value_counts().plot(kind='barh');

# %%
fo.Sport.value_counts().plot(kind='pie');

# %%
fo.Sport.value_counts().plot(kind='bar', color='maroon');

# %%
fo.Sport.value_counts().plot(kind='line', color='maroon', figsize=(12,4));

# %%
fo.Sport.value_counts().plot(kind='pie', colormap='Pastel1', figsize=(12,8));

# %%
import seaborn as sns

# %%
sns.countplot(x='Medal', data=df);

# %%
sns.countplot(x='Medal', data=df, hue='Gender');

# %%
df
# Out:
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
#        ...
# TGA       1
# DJI       1
# AHO       1
# BDI       1
# AFG       1
# Name: NOC, Length: 138, dtype: int64

# %%
Agg=df[(df.Edition == 2008) & (df.City == 'Beijing') & (df.NOC == 'CHN')]
display(Agg)
# Out:
#           City  Edition          Sport       Discipline           Athlete  \
# 27176  Beijing     2008       Aquatics           Diving       ZHOU, Luxin
# 27177  Beijing     2008       Aquatics           Diving         WANG, Xin
# 27178  Beijing     2008       Aquatics           Diving      CHEN, Ruolin
# 27180  Beijing     2008       Aquatics           Diving          QIN, Kai
# 27181  Beijing     2008       Aquatics           Diving         HE, Chong
# ...        ...      ...            ...              ...               ...
# 29138  Beijing     2008  Weightlifting    Weightlifting        LI, Hongli
# 29140  Beijing     2008  Weightlifting    Weightlifting          LU, Yong
# 29156  Beijing     2008      Wrestling  Wrestling Free.            XU, Li
# 29171  Beijing     2008      Wrestling  Wrestling Free.        WANG, Jiao
# 29204  Beijing     2008      Wrestling  Wrestling Gre-R  CHANG, Yongxiang
#
#        NOC Gender           Event Event_gender   Medal
# ...

# %%
Agg.Gender.value_counts()
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
Agg.Medal.value_counts()
# Out:
# Gold      74
# Bronze    57
# Silver    53
# Name: Medal, dtype: int64

# %%
Agg.Medal.value_counts().plot(kind='bar', color='green');

# %%
Agg[['Gender', 'Medal']].value_counts()
# Out:
# Gender  Medal
# Women   Bronze    46
#         Silver    42
#         Gold      40
# Men     Gold      34
#         Bronze    11
#         Silver    11
# dtype: int64

# %%
sns.countplot(x='Medal', data=Agg, hue='Gender', order=['Gold', 'Silver', 'Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# # How can you give the data more meaning? is there anything else you can change to make it more intuitive?

# %%
sns.countplot(x='Medal', data=Agg, hue='Gender', palette='bwr')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
sns.countplot(x='Medal', data=Agg, hue='Gender', palette='bwr', order=['Gold', 'Silver', 'Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
import pandas as pd

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %%
df.reset_index()
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 0             HAJOS, Alfred   Athens     1896   Aquatics         Swimming
# 1          HERSCHMANN, Otto   Athens     1896   Aquatics         Swimming
# 2         DRIVAS, Dimitrios   Athens     1896   Aquatics         Swimming
# 3        MALOKINIS, Ioannis   Athens     1896   Aquatics         Swimming
# 4        CHASAPIS, Spiridon   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 0             HAJOS, Alfred   Athens     1896   Aquatics         Swimming
# 1          HERSCHMANN, Otto   Athens     1896   Aquatics         Swimming
# 2         DRIVAS, Dimitrios   Athens     1896   Aquatics         Swimming
# 3        MALOKINIS, Ioannis   Athens     1896   Aquatics         Swimming
# 4        CHASAPIS, Spiridon   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
ath=df.set_index('Athlete')

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index()
# Out:
#                               City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                 Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes    London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes    London     1948  Gymnastics  Artistic G.  FIN
# ...                            ...      ...         ...          ...  ...
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTRAND, Per-Olof         Helsinki     1952    Aquatics     Swimming  SWE
#
# ...

# %%
ath.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
df[df.Athlete.str.contains('Usain')]
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
df.loc[df.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
df.iloc[[200, 250]]
# Out:
#               Athlete   City  Edition      Sport  Discipline  NOC Gender  \
# 200       KEMP, Peter  Paris     1900   Aquatics  Water polo  GBR    Men
# 250  BENNETT, Charles  Paris     1900  Athletics   Athletics  GBR    Men
#
#                   Event Event_gender   Medal
# 200          water polo            M    Gold
# 250  4000m steeplechase            M  Silver

# %%
df.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %% [markdown]
# # Questions: Plot the total number of medals awarded at each of the Olympic games throughout history

# %%
type(df.Edition.value_counts())
# Out:
# pandas.core.series.Series

# %%
df.Edition.value_counts().sort_index()
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
df.Edition.value_counts().sort_index().plot(kind='line', figsize=(10,12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Which countries did not win a medal in the 2008 Olympics? How many countries were there?

# %%
lo=df[df.Edition == 2008]
lo.head()
# Out:
#                 Athlete     City  Edition     Sport Discipline  NOC Gender  \
# 27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS    Men
# 27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS    Men
# 27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN    Men
# 27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN  Women
# 27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc = pd.read_csv('C:\\Users\\Famochy\\data\\Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc
# Out:
#              Country Int Olympic Committee code ISO code        Country.1
# 0        Afghanistan                        AFG       AF      Afghanistan
# 1            Albania                        ALB       AL          Albania
# 2            Algeria                        ALG       DZ          Algeria
# 3    American Samoa*                        ASA       AS  American Samoa*
# 4            Andorra                        AND       AD          Andorra
# ..               ...                        ...      ...              ...
# 196          Vietnam                        VIE       VN          Vietnam
# 197  Virgin Islands*                        ISV       VI  Virgin Islands*
# 198            Yemen                        YEM       YE            Yemen
# 199           Zambia                        ZAM       ZM           Zambia
# 200         Zimbabwe                        ZIM       ZW         Zimbabwe
#
# [201 rows x 4 columns]

# %% [markdown]
# To check the difference between country and country1

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code', inplace = True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008=lo.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# SUD      1
# EGY      1
# MDA      1
# TOG      1
# MRI      1
# Name: NOC, Length: 86, dtype: int64

# %% [markdown]
# Adding the medal_2008 Series to the noc dataframe

# %%
noc['medal_2008'] = medal_2008
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %% [markdown]
# The Groupby Object

# %%
df.groupby('Edition')

# %%
type(df.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(df.groupby('Edition'))
# Out:
# [(1896,
#                         Athlete    City  Edition          Sport  \
#   0               HAJOS, Alfred  Athens     1896       Aquatics
#   1            HERSCHMANN, Otto  Athens     1896       Aquatics
#   2           DRIVAS, Dimitrios  Athens     1896       Aquatics
#   3          MALOKINIS, Ioannis  Athens     1896       Aquatics
#   4          CHASAPIS, Spiridon  Athens     1896       Aquatics
#   ..                        ...     ...      ...            ...
#   146             JENSEN, Viggo  Athens     1896  Weightlifting
#   147       ELLIOTT, Launceston  Athens     1896  Weightlifting
#   148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
#   149            SCHUMANN, Carl  Athens     1896      Wrestling
#   150          TSITAS, Georgios  Athens     1896      Wrestling
#
#             Discipline  NOC Gender                        Event Event_gender  \
#   0           Swimming  HUN    Men               100m freestyle            M
# ...

# %% [markdown]
# Iterating through groups

# %%
for group_key, group_value in df.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#                       Athlete    City  Edition          Sport  \
# 0               HAJOS, Alfred  Athens     1896       Aquatics
# 1            HERSCHMANN, Otto  Athens     1896       Aquatics
# 2           DRIVAS, Dimitrios  Athens     1896       Aquatics
# 3          MALOKINIS, Ioannis  Athens     1896       Aquatics
# 4          CHASAPIS, Spiridon  Athens     1896       Aquatics
# ..                        ...     ...      ...            ...
# 146             JENSEN, Viggo  Athens     1896  Weightlifting
# 147       ELLIOTT, Launceston  Athens     1896  Weightlifting
# 148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
# 149            SCHUMANN, Carl  Athens     1896      Wrestling
# 150          TSITAS, Georgios  Athens     1896      Wrestling
#
#           Discipline  NOC Gender                        Event Event_gender  \
# 0           Swimming  HUN    Men               100m freestyle            M
# ...

# %%
type(group_value)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# GROUPBY COMPUTATIONS

# %%
df.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
df.groupby(['Edition', 'NOC', 'Medal']).agg('count')
# Out:
#                     Athlete  City  Sport  Discipline  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold          2     2      2           2       2      2
#         AUT Bronze        2     2      2           2       2      2
#             Gold          2     2      2           2       2      2
#             Silver        1     1      1           1       1      1
#         DEN Bronze        3     3      3           3       3      3
# ...                     ...   ...    ...         ...     ...    ...
# 2008    UZB Silver        2     2      2           2       2      2
#         VEN Bronze        1     1      1           1       1      1
#         VIE Silver        1     1      1           1       1      1
#         ZIM Gold          1     1      1           1       1      1
#             Silver        3     3      3           3       3      3
#
#                     Event_gender
# Edition NOC Medal
# 1896    AUS Gold               2
#         AUT Bronze             2
# ...

# %%
df.groupby(['Edition', 'NOC', 'Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %% [markdown]
# agg({:[...]})

# %%
df.groupby(['Edition', 'NOC', 'Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
df[df.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min', 'max', 'count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %% [markdown]
# CHALLENGE QUESTIONS: USING GROUPBY(), PLOT THE TOTAL NUMBER OF MEDALS AWARDED AT EACH OF THE OLYMPIC GAMES THROUGHOUT HISTORY

# %%
df.groupby('Edition').size().plot()
# Out:
# <AxesSubplot:xlabel='Edition'>

# %% [markdown]
# CREATE A LIST SHOWING THE TOTAL NUMBER OF MEDALS WON FOR EACH COUNTRY OVER THE HISTORY OF THE OLYMPICS. FOR EACH COUNTRY, INCLUDE THE YEAR OF THE FIRST AND MOST RECENT OLYMPIC MEDAL WINS.

# %%
df
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 0             HAJOS, Alfred   Athens     1896   Aquatics         Swimming
# 1          HERSCHMANN, Otto   Athens     1896   Aquatics         Swimming
# 2         DRIVAS, Dimitrios   Athens     1896   Aquatics         Swimming
# 3        MALOKINIS, Ioannis   Athens     1896   Aquatics         Swimming
# 4        CHASAPIS, Spiridon   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
df.groupby('NOC').agg({'Edition':['count','min', 'max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %% [markdown]
# ATHLETE WINNING MEDALS IN BEIJING OLYMPICS 100M OR 200M TRACK EVENT FOR 2008 EDITION FOR RESHAPING--UNSTACK

# %%
jp=df[(df.Edition == 2008) & ((df.Event == '100m') | (df.Event == '200m'))]
jp
# Out:
#                         Athlete     City  Edition      Sport Discipline  NOC  \
# 27551               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27552               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27553         THOMPSON, Richard  Beijing     2008  Athletics  Athletics  TRI
# 27554        FRASER, Shelly-ann  Beijing     2008  Athletics  Athletics  JAM
# 27555          SIMPSON, Sherone  Beijing     2008  Athletics  Athletics  JAM
# 27556           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27569               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27570               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27571           CRAWFORD, Shawn  Beijing     2008  Athletics  Athletics  USA
# 27572           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27573  CAMPBELL-BROWN, Veronica  Beijing     2008  Athletics  Athletics  JAM
# ...

# %%
gb=jp.groupby(['NOC', 'Gender', 'Discipline', 'Event']).size()
gb
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
gb.unstack(['Discipline', 'Event'])
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0
